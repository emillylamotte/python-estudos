# %% [markdown]
# <a href="https://colab.research.google.com/github/emillylamotte/python_estudos/blob/main/Aula04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Tabela de frequência, gráfico de dispersão, tabela e gráfico de correlação

# %% [markdown]
# ####Visualizando a base de dados

# %%
import pandas as pd
#Importando a base de dados
url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'
dados = pd.read_csv(url_dados, compression = 'zip')#importa do git, informa que está compactado

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
#Tabela de frequência 
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'])
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24              301       3585
#      48              343       4011
#      72              307       3600
# D2   24              305       3581
#      48              305       3591
#      72              305       3580

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], normalize='index')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.077458   0.922542
#      48         0.078778   0.921222
#      72         0.078577   0.921423
# D2   24         0.078487   0.921513
#      48         0.078285   0.921715
#      72         0.078507   0.921493

# %%
#Agregando o valor de média dos valores de g-0
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], values=dados['g-0'], aggfunc='mean')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24        -0.251760   0.367996
#      48        -0.122773   0.412469
#      72        -0.295271   0.286250
# D2   24         0.010754   0.115253
#      48         0.013174   0.214480
#      72         0.070250   0.253439

# %%
dados[['g-0', 'g-3']]
# Out:
#           g-0     g-3
# 0      1.0620 -0.6208
# 1      0.0743  0.0604
# 2      0.6280 -0.0764
# 3     -0.5138  0.5288
# 4     -0.3254  0.6919
# ...       ...     ...
# 23809  0.1394 -0.5080
# 23810 -1.3260  0.9905
# 23811  0.3942 -0.7389
# 23812  0.6660  0.2044
# 23813 -0.8598  0.7952
#
# [23814 rows x 2 columns]

# %%
#Gráfico de visualização de dispersão entre compostos
#Cada ponto é uma linha do df
import seaborn as sns
sns.scatterplot(x='g-0', y='g-3', data=dados)

# %%
sns.scatterplot(x='g-0', y='g-8', data=dados)

# %%
sns.lmplot(x='g-0', y='g-8', data=dados, line_kws={'color':'red'})

# %%
sns.lmplot(x='g-0', y='g-8', data=dados, line_kws={'color':'red'}, col='tratamento', row='tempo')

# %%
#Correlação entre os compostos, quanto mais próxima de -1 ou 1, maior a relação entre as variáveis
#Nem sempre alta correlação significa causalidade!!!
dados.loc[:,'g-0':'g-771'].corr()
# Out:
#             g-0       g-1       g-2  ...     g-769     g-770     g-771
# g-0    1.000000  0.086032  0.176188  ... -0.127375 -0.514201  0.405908
# g-1    0.086032  1.000000 -0.054518  ... -0.006866 -0.095108 -0.032233
# g-2    0.176188 -0.054518  1.000000  ...  0.014489 -0.078661  0.103985
# g-3    0.011266 -0.027855  0.042633  ... -0.206077 -0.002142  0.058219
# g-4    0.403153  0.193647  0.013968  ... -0.172727 -0.363673  0.250713
# ...         ...       ...       ...  ...       ...       ...       ...
# g-767 -0.052622 -0.003378 -0.053149  ...  0.065450  0.008603 -0.001136
# g-768  0.300241 -0.030756  0.115415  ...  0.079364 -0.382607  0.351651
# g-769 -0.127375 -0.006866  0.014489  ...  1.000000  0.135853 -0.083713
# g-770 -0.514201 -0.095108 -0.078661  ...  0.135853  1.000000 -0.425063
# g-771  0.405908 -0.032233  0.103985  ... -0.083713 -0.425063  1.000000
#
# [772 rows x 772 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt

corr = dados.loc[:,'g-0':'g-50'].corr()
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))
# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))
# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)
# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, center=0, square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
corr_celular = dados.loc[:,'c-0':'c-50'].corr()

# %%
corr_celular = dados.loc[:,'c-0':'c-50'].corr()
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))
# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))
# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)
# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_celular, mask=mask, cmap=cmap, center=0, square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# ##**Desafios aula 3:**
# 1. Criar tabelas de frequência com pandas.groupby();
# 2. Normalizar o crosstab pela coluna;
# 3. Explorar outros agregadores aggfunc;
# 4. Explorar o melt;
# 5. Calcular e analisar a correlação entre os G e C;
# 6. Estudar o código de plotagem da matriz de correlação (heatmap);
# 7. Refletir sobre os efeitos biológicos;
# 8. Resumo do que você aprendeu com os dados.

# %% [markdown]
# #Aula 4

# %% [markdown]
# ###Nova base de dados: resultados

# %%
dados_resultados = pd.read_csv('https://github.com/alura-cursos/imersao-dados-desafio-final/blob/main/Dados/dados_resultados.csv?raw=true')
dados_resultados.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %%
dados_resultados['acetylcholine_receptor_agonist'].unique()
# Out:
# array([0, 1])

# %%
#Mecanismo mais ativado (pelas colunas), qual mecanismno foi mais ativado em todos os experimentos
contagem_moa = dados_resultados.select_dtypes('int64').sum().sort_values(ascending=False)
contagem_moa
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %%
#Mecanismo mais ativado (pelas linhas), quantos mecanismos de ação o experimento ativou
dados_resultados.drop('id', axis=1).sum(axis=1)
# Out:
# 0        1
# 1        0
# 2        3
# 3        0
# 4        1
#         ..
# 23809    1
# 23810    1
# 23811    0
# 23812    1
# 23813    0
# Length: 23814, dtype: int64

# %% [markdown]
# ###Merge de dados

# %%
#Verificando onde as enzimas são ativadas
dados_resultados['n_moa']!= 0
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 23809     True
# 23810     True
# 23811    False
# 23812     True
# 23813    False
# Name: n_moa, Length: 23814, dtype: bool

# %%
#Juntando as bases de dados, resultados e experimentos - Merge
dados_resultados['n_moa'] = dados_resultados.drop('id', axis=1).sum(axis=1)#adicionando uma coluna

# %%
dados_resultados['ativo_moa'] = (dados_resultados['n_moa']!= 0)
dados_resultados.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0  id_000644bb2                            0  ...    3.0       True
# 1  id_000779bfc                            0  ...    0.0      False
# 2  id_000a6266a                            0  ...    7.0       True
# 3  id_0015fd391                            0  ...    0.0      False
# 4  id_001626bd3                            0  ...    3.0       True
#
# [5 rows x 209 columns]

# %%
#Merge
dados_combinados = pd.merge(dados, dados_resultados[['id','n_moa','ativo_moa']], on='id')
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ...    c-98    c-99  n_moa  ativo_moa
# 0  id_000644bb2  com_droga     24   D1  ...  0.3801  0.4176    3.0       True
# 1  id_000779bfc  com_droga     72   D1  ...  0.6077  0.7371    0.0      False
# 2  id_000a6266a  com_droga     48   D1  ... -1.4080  0.6931    7.0       True
# 3  id_0015fd391  com_droga     48   D1  ... -0.3876 -0.8154    0.0      False
# 4  id_001626bd3  com_droga     72   D2  ... -0.3786  0.7125    3.0       True
#
# [5 rows x 879 columns]

# %%
dados_combinados.query('tratamento== "com_controle"')['ativo_moa'].value_counts()#verificando se os tratamentos com controle ativaram algo
# Out:
# False    1866
# Name: ativo_moa, dtype: int64

# %%
dados_combinados.query('tratamento== "com_droga"')['ativo_moa'].value_counts()#verificando se os tratamentos com droga ativaram algo, ver o que teve efeito
# Out:
# True     14447
# False     7501
# Name: ativo_moa, dtype: int64

# %%
#efeito de ativação dos compostos pro gene 0, ca=com_controle
composto_principal=dados_combinados['droga'].value_counts().index[:5]
plt.figure(figsize=(12,8))
sns.boxplot(data=dados_combinados.query('droga in @composto_principal'), y='g-0', x='droga', hue='ativo_moa')

# %% [markdown]
# ##**Desafios aula 4:**
# 1. Encontrar o top 10 das ações do MOA(inibidor, antagonista...);
# 2. Criar a coluna eh_controle para quando na linha tratamento == com_controle;
# 3. Criar três colunas para indicar o tempo 24, 48, 72;
# 4. Ler sobre Merge, combinações de dataframes;
# 5. Fazer análise mais detalhada considerando tempo e dose, para comparar as distribuições (boxplot)(Escolher alguma droga e comparar com controle)
# 6. Descobrir se temos algum composto que dependendo da configuração do experimento, ativa ou não ativa algum MOA;
# 7. Descobrir se temos algum composto que dependendo da configuração do experimento, ativa MOA's;
# 8. Resumo do que você aprendeu com os dados
